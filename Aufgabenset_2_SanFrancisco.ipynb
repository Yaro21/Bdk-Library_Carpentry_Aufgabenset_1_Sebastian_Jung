# %%
import urllib.request
import pandas as pd

# %%
csv_file = pd.read_csv(r"C:\Users\Sebastian Jung\Desktop\Library_Usage.csv")

# %%
#print(csv_file)

# %%
csv_file.keys()
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %%
#1. Alle Nutzer im Alter zwischen 25 und 34 , die mehr als 10 Medien ausgeliehen haben.
#2. Alle Nutzer die per Post benachrichtigt werden und zur Nutzergruppe Senioren gehören.

# %%
#1. Aufgabe
Nutzergruppe = csv_file[csv_file["Age Range"] == "25 to 34 years"]
Mediennutzung = csv_file[csv_file["Total Checkouts"] >= 10]
Mediennutzung_Nutzergruppe = pd.merge(Nutzergruppe, Mediennutzung)
Mediennutzung_Nutzergruppe.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 0                  ADULT               31              22
# 1                 0                  ADULT             3002            1689
# 2                 0                  ADULT               20               0
# 3                 0                  ADULT              102              31
# 4                 0                  ADULT               45              11
#
#         Age Range Home Library Code Home Library Definition  \
# 0  25 to 34 years                S7                  Sunset
# 1  25 to 34 years                P5                 Portola
# 2  25 to 34 years                S7                  Sunset
# 3  25 to 34 years                M6                 Mission
# 4  25 to 34 years                P3                Parkside
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# ...

# %%
#2. Aufgabe
Postbenachrichtigung = csv_file[csv_file["Notice Preference Definition"] == "print"]
Nutzergruppe_2 = csv_file[csv_file["Patron Type Definition"] == "SENIOR"]
Postbenachrichtigung_Nutzergruppe_2 = pd.merge(Postbenachrichtigung, Nutzergruppe_2)
Postbenachrichtigung_Nutzergruppe_2.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 3                 SENIOR                0               0
# 1                 3                 SENIOR              259               0
# 2                 3                 SENIOR                0               0
# 3                 3                 SENIOR                0               0
# 4                 3                 SENIOR                0               0
#
#            Age Range Home Library Code Home Library Definition  \
# 0     65 to 74 years                O2              Ocean View
# 1     60 to 64 years                 X            Main Library
# 2  75 years and over                 X            Main Library
# 3  75 years and over                 X            Main Library
# 4  75 years and over                 X            Main Library
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# ...
